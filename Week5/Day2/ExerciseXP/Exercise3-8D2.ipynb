# %% [markdown]
# # 🌟 Exercise 3: Grouping (Users)

# %%
import numpy as np
import pandas as pd

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
chipo
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Use the groupby() function to find the mean age per occupation.

# %%
chipo[['occupation','age']].groupby('occupation').mean('age')
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# # 🌟 Exercise 4: Merge (All_data, All_data_col, Data3)

# %% [markdown]
# ##### Create three DataFrames based on the given raw data (define what the raw data looks like and what data should be included in ‘data1’, ‘data2’, and ‘data3’).

# %%
data1 = pd.DataFrame({
    'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
    'Max Speed': [380., 370., 24., 26.],
    'Weight': [1, 1.5, 0.3, 0.5]
})
data2 = pd.DataFrame({
    'Animal': ['Bear', 'Deer', 'Tiger', 'Honey badger'],
    'Max Speed': [40., 65., 50., 20.],
    'Weight': [350, 160, 150, 8]
})
data3 = pd.DataFrame({
    'Animal': ['Wolf', 'Fox', 'Boar'],
    'Max Speed': [65., 50., 40.],
    'Weight': [45, 7, 80]
})

# %% [markdown]
# Merge the two dataframes ‘data1’ and ‘data2’ along rows using the concat() function and assign it to ‘all_data’.

# %%
all_data = pd.concat([data1, data2])

# %%
all_data
# Out:
#          Animal  Max Speed  Weight
# 0        Falcon      380.0     1.0
# 1        Falcon      370.0     1.5
# 2        Parrot       24.0     0.3
# 3        Parrot       26.0     0.5
# 0          Bear       40.0   350.0
# 1          Deer       65.0   160.0
# 2         Tiger       50.0   150.0
# 3  Honey badger       20.0     8.0

# %% [markdown]
# Merge ‘data1’ and ‘data2’ along columns using concat() and assign it to ‘all_data_col’.

# %%
all_data_col = pd.concat([data1, data2], axis=1)

# %%
all_data_col
# Out:
#    Animal  Max Speed  Weight        Animal  Max Speed  Weight
# 0  Falcon      380.0     1.0          Bear       40.0     350
# 1  Falcon      370.0     1.5          Deer       65.0     160
# 2  Parrot       24.0     0.3         Tiger       50.0     150
# 3  Parrot       26.0     0.5  Honey badger       20.0       8

# %% [markdown]
# ## Exercise 5: Deleting (Iris)

# %%
colnames=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', sep=',', names=colnames)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.isnull(iris).sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## 🌟 Exercise 6: Creating Series And DataFrames (Pokemon)

# %%
pokemon_dict = {'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
    'hp': [45, 39, 44, 45],
    'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
    'pokedex': ['yes', 'no', 'yes', 'no'],
    'type': ['grass', 'fire', 'water', 'bug']}

# %%
pokemon = pd.DataFrame.from_dict(pokemon_dict)

# %%
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# #### Rearrange the columns in the order: ‘name’, ‘type’, ‘hp’, ‘evolution’, ‘pokedex’ using simple DataFrame indexing.

# %%
cols = pokemon.columns.tolist()
cols
# Out:
# ['evolution', 'hp', 'name', 'pokedex', 'type']

# %%
cols = [cols[2]] + [cols[4]] + [cols[1]] + [cols[0]] + [cols[3]]
cols
# Out:
# ['name', 'type', 'hp', 'evolution', 'pokedex']

# %%
pokemon[cols]
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ## 🌟 Exercise 7: Descriptive Statistics (Baby_names)

# %%
baby_names = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv', sep=',')

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
baby_names.drop(columns=['Unnamed: 0','Id'])
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ## 🌟 Exercise 8: Handling Time Series Data (Investor_data)

# %%
investor_data = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv', sep=',')

# %% [markdown]
# Determine the frequency of the dataset.

# %%
investor_data['Date'] = pd.to_datetime(investor_data['Date'], format='%Y-%m-%d')
investor_data.head(10)
# Out:
#         Date  Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# 0 2012-12-05         -7426            -6060         -1367     -74        5317
# 1 2012-12-12         -8783            -7520         -1263     123        1818
# 2 2012-12-19         -5496            -5470           -26     -73         103
# 3 2012-12-26         -4451            -4076          -375     550        2610
# 4 2013-01-02        -11156            -9622         -1533    -158        2383
# 5 2013-01-09         14817             7995          6821    2888        9766
# 6 2014-04-02          3155              938          2217     265        3379
# 7 2014-04-09          5761             2080          3681    1482        1609
# 8 2014-04-16          2286              634          1652    1186         633
# 9 2014-04-23          3530             1392          2138    1239        1984
#
#    Taxable Bond  Municipal Bond  Total
# 0          4210            1107  -2183
# ...

# %%
investor_data = investor_data.set_index('Date')

# %%
investor_data.index
# Out:
# DatetimeIndex(['2012-12-05', '2012-12-12', '2012-12-19', '2012-12-26',
#                '2013-01-02', '2013-01-09', '2014-04-02', '2014-04-09',
#                '2014-04-16', '2014-04-23', '2014-04-30', '2014-05-07',
#                '2014-05-14', '2014-05-21', '2014-05-28', '2014-06-04',
#                '2014-06-11', '2014-06-18', '2014-06-25', '2014-07-02',
#                '2014-07-09', '2014-07-30', '2014-08-06', '2014-08-13',
#                '2014-08-20', '2014-08-27', '2014-09-03', '2014-09-10',
#                '2014-11-05', '2014-11-12', '2014-11-19', '2014-11-25',
#                '2015-01-07', '2015-01-14', '2015-01-21', '2015-01-28',
#                '2015-02-04', '2015-02-11', '2015-03-04', '2015-03-11',
#                '2015-03-18', '2015-03-25', '2015-04-01', '2015-04-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
my_series = investor_data.index

# %%
my_series
# Out:
# DatetimeIndex(['2012-12-05', '2012-12-12', '2012-12-19', '2012-12-26',
#                '2013-01-02', '2013-01-09', '2014-04-02', '2014-04-09',
#                '2014-04-16', '2014-04-23', '2014-04-30', '2014-05-07',
#                '2014-05-14', '2014-05-21', '2014-05-28', '2014-06-04',
#                '2014-06-11', '2014-06-18', '2014-06-25', '2014-07-02',
#                '2014-07-09', '2014-07-30', '2014-08-06', '2014-08-13',
#                '2014-08-20', '2014-08-27', '2014-09-03', '2014-09-10',
#                '2014-11-05', '2014-11-12', '2014-11-19', '2014-11-25',
#                '2015-01-07', '2015-01-14', '2015-01-21', '2015-01-28',
#                '2015-02-04', '2015-02-11', '2015-03-04', '2015-03-11',
#                '2015-03-18', '2015-03-25', '2015-04-01', '2015-04-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
pd.infer_freq(my_series)
