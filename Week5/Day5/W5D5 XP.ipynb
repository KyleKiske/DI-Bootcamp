# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
boston = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv', sep=',')

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# #### Explore the Data - Use pandas, numpy and matplotlib to explore the dataset.

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
fig, axes = plt.subplots(len(boston.columns)//7, 7, figsize=(40, 10))

i = 0
for triaxis in axes:
    for axis in triaxis:
        boston.hist(column = boston.columns[i], bins = 100, ax=axis)
        i = i+1
plt.show()

# %%
fig, axes = plt.subplots(len(boston.columns)//4+1, 4, figsize=(20, 20))

i = 0
for triaxis in axes:
    for axis in triaxis:
        if i == len(boston.columns):
            break
        boston.plot(kind='scatter', x='medv',y=boston.columns[i], ax=axis)
        i = i+1
plt.show()

# %% [markdown]
# #### Preprocess the Data: Now, we need to make sure our data is clean and ready to use:

# %%
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
boston.dropna()
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
normalized_df=(boston-boston.min())/(boston.max()-boston.min())
normalized_df
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %% [markdown]
# #### Categorical Variables: The Boston Housing dataset doesn’t contain categorical variables (variables with set categories), but it’s useful to know how to handle them. Practice this by creating a fake categorical variable.

# %%
normalized_df['age_category'] = pd.cut(normalized_df['age'],bins=[0.0,0.30,0.60,0.90],labels=['new','old','very_old'])
normalized_df.head()
# Out:
#        crim    zn     indus  chas       nox        rm       age       dis  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         rad       tax   ptratio         b     lstat      medv age_category
# 0  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222     very_old
# 1  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889     very_old
# 2  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000          old
# 3  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111          old
# 4  0.086957  0.066794  0.648936  1.000000  0.099338  0.693333          old

# %% [markdown]
# #### Correlations: See how much each variable affects the house price (MEDV). This is done by calculating the correlation matrix (a table showing correlation coefficients between variables).

# %%
correlation_matrix = normalized_df.corr(numeric_only=True)
correlation_matrix['medv'].sort_values()
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# b          0.333461
# zn         0.360445
# rm         0.695360
# medv       1.000000
# Name: medv, dtype: float64

# %%
sns.heatmap(correlation_matrix[['medv']].sort_values(by='medv'), vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Feature Engineering: Create a new feature/column from the existing ones. This might enhance data understanding or prediction accuracy.

# %%
normalized_df['feature'] = normalized_df['lstat'] * normalized_df['rm']
normalized_df
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %% [markdown]
# ## Part II

# %% [markdown]
# #### Analyse the relationship between Property Age and Price

# %%
new_properties = boston[boston['age'] <= 35]
old_properties = boston[(boston['age'] <= 70) & (boston['age'] > 35)]
very_old_properties = boston[boston['age'] > 70]

fig, axs = plt.subplots(3, 1)
fig.tight_layout()
axs[0].set(xlabel='median value', ylabel='age')
axs[0].scatter(new_properties['medv'], new_properties['age'])
axs[1].set(xlabel='median value', ylabel='age')
axs[1].scatter(old_properties['medv'], old_properties['age'])
axs[2].set(xlabel='median value', ylabel='age')
axs[2].scatter(very_old_properties['medv'], very_old_properties['age'])
plt.show()

# %% [markdown]
# ## Part III

# %% [markdown]
# #### Instruction : Analyse the Neighborhood Crime Rate Impact on Prices

# %%
boston['CRIM_BIN'] = pd.cut(boston['crim'], bins=[0, 1, 5, 10, 20, max(boston['crim'])], labels=['0-1', '1-5', '5-10', '10-20', '20+'])
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv CRIM_BIN
# 0       15.3  396.90   4.98  24.0      0-1
# ...

# %%
avg_MEDV_per_CRIM_BIN = boston.groupby('CRIM_BIN')['medv'].mean()
avg_MEDV_per_CRIM_BIN
# Out:
# CRIM_BIN
# 0-1      25.110843
# 1-5      21.469118
# 5-10     18.048077
# 10-20    13.694444
# 20+       9.633333
# Name: medv, dtype: float64

# %%
fig, axs = plt.subplots()
avg_MEDV_per_CRIM_BIN.plot(kind='line', ax=axs, xlabel='average crime', ylabel='median value')
plt.show()
